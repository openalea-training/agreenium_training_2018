# %% [markdown]
# # I. 3D model

# %%
from simple_maize import *
from matplotlib.pylab import plot, show, xlim, ylim, axes
import numpy
from TD_maize import maize,display,generate_mtg, illuminate,plant_irradiance, process
# %pylab inline
pylab.rcParams['figure.figsize'] = (5, 5)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['display']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ## Parameters range are done in TD_sensitivity_Agreenium.R

# %% [markdown]
# ## I.1 plant height

# %%
phytomer=16
nb_young_phy = int(round((phytomer - 1.95) / 1.84 / 1.3))
pseudostem_dist=1.4
pseudostem_height=20
stem_dist=1.
pseudostem = geometric_dist(height=pseudostem_height, nb_phy=nb_young_phy,q=pseudostem_dist)

plant_height_min=50
plant_height_max=300

stem_min = geometric_dist(height=plant_height_min - pseudostem_height,nb_phy=phytomer - nb_young_phy, q=stem_dist)
stem_max = geometric_dist(height=plant_height_max - pseudostem_height,nb_phy=phytomer - nb_young_phy, q=stem_dist)

stem_min,stem_max
# Out:
# ([3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0],
#  [28.0, 28.0, 28.0, 28.0, 28.0, 28.0, 28.0, 28.0, 28.0, 28.0])

# %% [markdown]
# ## I.2 Leaf area distribution along the stem

# %% [markdown]
# relative position of the leaf with highest area (rmax)

# %%
rmax_min=0.1
rmax_max=0.9
ymin=bell_shaped_dist(plant_area=1,nb_phy=15,rmax=rmax_min,skew=0.15)
ymax=bell_shaped_dist(plant_area=1,nb_phy=15,rmax=rmax_max,skew=0.15)
plot(ymin)
plot(ymax)

# %% [markdown]
# skewness of leaf area distribution (skew)

# %%
skew_min=0.05
skew_max=1
ymin=bell_shaped_dist(plant_area=1,nb_phy=15,rmax=0.7,skew=skew_min)
ymax=bell_shaped_dist(plant_area=1,nb_phy=15,rmax=0.7,skew=skew_max)
plot(ymin)
plot(ymax)

# %% [markdown]
# ## I.3 leaf shape

# %% [markdown]
# ratio widht/length (wl)

# %%
s,r=sr_prevot() #relative shape

leaf_area=0.5

wl_min=0.1
l_min=sqrt(leaf_area/(0.75*wl_min))
w_min=l_min*wl_min
s_min,r_min=s*l_min,r*w_min

wl_max=0.5
l_max=sqrt(leaf_area/(0.75*wl_max))
w_max=l_max*wl_max
s_max,r_max=s*l_max,r*w_max

plot(s_min,r_min)
plot(s_max,r_max)

# %% [markdown]
# ##  I.4 Leaf curvature

# %% [markdown]
# ### II.4.1 Base function

# %%
leaf_shape_perez(nb_segment=10,insertion_angle=65, delta_angle=180, coef_curv=-0.2)
# Out:
# (array([0.        , 0.09063078, 0.18229699, 0.27673833, 0.3746242 ,
#         0.47460233, 0.5720805 , 0.65792097, 0.71778675, 0.73396768,
#         0.69299361]),
#  array([ 0.        ,  0.04226183,  0.08222813,  0.11510416,  0.13555794,
#          0.1376493 ,  0.11533324,  0.06403593, -0.01606455, -0.11474676,
#         -0.20596696]))

# %%
x,y=leaf_shape_perez(nb_segment=100,insertion_angle=65, delta_angle=180, coef_curv=-0.2)
plot(x,y)

# %% [markdown]
# ### I.4.2 Variation of curvature with leaf rank

# %%
def leaf_shape_rank(rank=1,nb_segment=100,incli_top=50, delta_angle_top=180):
    incli_base=75
    delta_angle_base=250
    phytomer=16
    dinc = float(incli_top - incli_base) / (phytomer - 1)
    incli = incli_base + (rank -1) * dinc
    ddel = float(delta_angle_top - delta_angle_base) / (phytomer - 1)
    delta_angle = delta_angle_base + (rank - 1) * ddel
    return leaf_shape_perez(nb_segment=nb_segment,insertion_angle=incli, delta_angle=delta_angle, coef_curv=-0.2)

# %% [markdown]
# #### Curvature of top leaf (rank16)

# %% [markdown]
# Variation of inclination (incli_top)

# %%
rank=16
incli_top_min=5
incli_top_max=75

x_min,y_min=leaf_shape_rank(rank=rank,incli_top=incli_top_min, delta_angle_top=180)
x_max,y_max=leaf_shape_rank(rank=rank,incli_top=incli_top_max, delta_angle_top=180)

plot(x_min,y_min)
plot(x_max,y_max)
xlim(0,1.2)
ylim(-0.6,0.6)
#numpy.sqrt(numpy.diff(x_max)**2 + numpy.diff(y_max)**2).sum()
# Out:
# (-0.6, 0.6)

# %% [markdown]
# Variation of curvature (delta_angle_top)

# %%
rank=16
delta_angle_top_min=0
delta_angle_top_max=250

x_min,y_min=leaf_shape_rank(rank=rank,incli_top=30, delta_angle_top=delta_angle_top_min)
x_max,y_max=leaf_shape_rank(rank=rank,incli_top=30, delta_angle_top=delta_angle_top_max)

plot(x_min,y_min)
plot(x_max,y_max)
xlim(0,1.2)
ylim(-0.3,0.9)
#numpy.sqrt(numpy.diff(x_max)**2 + numpy.diff(y_max)**2).sum()
# Out:
# (-0.3, 0.9)

# %% [markdown]
# #### Curvature at a given rank (rank=5)

# %% [markdown]
# Variation of inclination (incli_top)

# %%
rank=5
incli_top_min=5
incli_top_max=75
x_min,y_min=leaf_shape_rank(rank=rank,incli_top=incli_top_min, delta_angle_top=180)
x_max,y_max=leaf_shape_rank(rank=rank,incli_top=incli_top_max, delta_angle_top=180)
plot(x_min,y_min)
plot(x_max,y_max)
xlim(0,1.2)
ylim(-0.6,0.6)
#numpy.sqrt(numpy.diff(x_max)**2 + numpy.diff(y_max)**2).sum()
# Out:
# (-0.6, 0.6)

# %% [markdown]
# Variation of curvature (delta_angle_top)

# %%
rank=5
delta_angle_top_min=0
delta_angle_top_max=250

x_min,y_min=leaf_shape_rank(rank=rank,incli_top=30, delta_angle_top=delta_angle_top_min)
x_max,y_max=leaf_shape_rank(rank=rank,incli_top=30, delta_angle_top=delta_angle_top_max)

plot(x_min,y_min)
plot(x_max,y_max)

xlim(0,1.2)
ylim(-0.3,0.6)
# Out:
# (-0.3, 0.6)

# %% [markdown]
# ## I.5 Phyllotaxis

# %% [markdown]
# phyllotactic_angle

# %%
def pol2cart(rho, phi):
    x = rho * np.cos(phi)
    y = rho * np.sin(phi)
    return(x, y)

phytomer=16
phyllotactic_angle_min=0
phyllotactic_angle_max=180

az_min=leaf_azimuth(size=phytomer, phyllotactic_angle=phyllotactic_angle_min, phyllotactic_deviation=10, plant_orientation=0, spiral=False)*pi/180
az_max=leaf_azimuth(size=phytomer, phyllotactic_angle=phyllotactic_angle_max, phyllotactic_deviation=10, plant_orientation=0, spiral=False)*pi/180

x_min,y_min=pol2cart(rho=1,phi=az_min)
x_max,y_max=pol2cart(rho=1,phi=az_max)
    
# %pylab inline
pylab.rcParams['figure.figsize'] = (5, 5)
#scatter(x,y,c=numpy.arange(phytomer))
scatter(x_min,y_min,c='blue')
scatter(x_max,y_max,c='green')
xlim(-1.1,1.1)
ylim(-1.1,1.1)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['rank']
# `%matplotlib` prevents importing * from pylab and numpy
# (-1.1, 1.1)

# %% [markdown]
# phyllotactic_deviation

# %%
def pol2cart(rho, phi):
    x = rho * np.cos(phi)
    y = rho * np.sin(phi)
    return(x, y)

phytomer=16
phyllotactic_deviation_min=0
phyllotactic_deviation_max=90

az_min=leaf_azimuth(size=phytomer, phyllotactic_angle=180, phyllotactic_deviation=phyllotactic_deviation_min, plant_orientation=0, spiral=False)*pi/180
az_max=leaf_azimuth(size=phytomer, phyllotactic_angle=180, phyllotactic_deviation=phyllotactic_deviation_max, plant_orientation=0, spiral=False)*pi/180

x_min,y_min=pol2cart(rho=1,phi=az_min)
x_max,y_max=pol2cart(rho=1,phi=az_max)
    
# %pylab inline
pylab.rcParams['figure.figsize'] = (5, 5)
#scatter(x,y,c=numpy.arange(phytomer))
scatter(x_min,y_min,c='blue')
scatter(x_max,y_max,c='green')
xlim(-1.1,1.1)
ylim(-1.1,1.1)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (-1.1, 1.1)

# %% [markdown]
# # II. Visualisation of 3D reconstructions and estimation of light interception

# %% [markdown]
# ## II.1 Generate the mtg

# %%
g=generate_mtg(plant_height=300,
                 rmax=0.5,
                 skew=0.2,
                 wl=0.15,
                 incli_base=75,
                 incli_top=15,
                 delta_angle_base=250,
                 delta_angle_top=35,
                 plant_orientation=0,
                 phyllotactic_angle=180,
                 phyllotactic_deviation=10,
                 nb_leaf_segment=10)

# %% [markdown]
# ## II.2 Illuminate the 3D plant

# %%
plant_irradiance(g, isolated=True, illuminated=None)
# Out:
# {'Area': 0.8376534793,
#  'Area_leaf': 0.6964331897,
#  'Ei': 0.6550364012727297,
#  'Ei_leaf': 0.7225305657168497}

# %% [markdown]
# ## II.3 Visualisation

# %%
# %gui qt4
from TD_maize import display

# %% [markdown]
# Raw visualisation

# %%
display(g,light=False)

# %% [markdown]
# Visualisation with irradiance

# %%
display(g,light=True)

# %% [markdown]
# # III. Run simulation for sensitivity analysis

# %%
input='planMorris.csv'
output='resMorris_isolated.csv'

process(path_input=input, path_output=output, nb_process=4, isolated=True)
# Out:
# run_sim_xrun : 0 / 300
# run_sim_xrun : 1 / 300
# run_sim_xrun : 2 / 300
# run_sim_xrun : 3 / 300
# run_sim_xrun : 4 / 300
# run_sim_xrun : 5 / 300
# run_sim_xrun : 6 / 300
# run_sim_xrun : 7 / 300
# run_sim_xrun : 8 / 300
# run_sim_xrun : 9 / 300
# run_sim_xrun : 10 / 300
# run_sim_xrun : 11 / 300
# run_sim_xrun : 12 / 300
# run_sim_xrun : 13 / 300
# run_sim_xrun : 14 / 300
# run_sim_xrun : 15 / 300
# run_sim_xrun : 16 / 300
# run_sim_xrun : 17 / 300
# run_sim_xrun : 18 / 300
# run_sim_xrun : 19 / 300
# run_sim_xrun : 20 / 300
# run_sim_xrun : 21 / 300
# run_sim_xrun : 22 / 300
# run_sim_xrun : 23 / 300
# run_sim_xrun : 24 / 300
# run_sim_xrun : 25 / 300
# run_sim_xrun : 26 / 300
# run_sim_xrun : 27 / 300
# run_sim_xrun : 28 / 300
# run_sim_xrun : 29 / 300
# run_sim_xrun : 30 / 300
# run_sim_xrun : 31 / 300
# run_sim_xrun : 32 / 300
# run_sim_xrun : 33 / 300
# run_sim_xrun : 34 / 300
# run_sim_xrun : 35 / 300
# run_sim_xrun : 36 / 300
# run_sim_xrun : 37 / 300
# run_sim_xrun : 38 / 300
# run_sim_xrun : 39 / 300
# run_sim_xrun : 40 / 300
# run_sim_xrun : 41 / 300
# run_sim_xrun : 42 / 300
# run_sim_xrun : 43 / 300
# run_sim_xrun : 44 / 300
# run_sim_xrun : 45 / 300
# run_sim_xrun : 46 / 300
# run_sim_xrun : 47 / 300
# run_sim_xrun : 48 / 300
# run_sim_xrun : 49 / 300
# run_sim_xrun : 50 / 300
# run_sim_xrun : 51 / 300
# run_sim_xrun : 52 / 300
# run_sim_xrun : 53 / 300
# run_sim_xrun : 54 / 300
# run_sim_xrun : 55 / 300
# run_sim_xrun : 56 / 300
# run_sim_xrun : 57 / 300
# run_sim_xrun : 58 / 300
# run_sim_xrun : 59 / 300
# run_sim_xrun : 60 / 300
# run_sim_xrun : 61 / 300
# run_sim_xrun : 62 / 300
# run_sim_xrun : 63 / 300
# run_sim_xrun : 64 / 300
# run_sim_xrun : 65 / 300
# run_sim_xrun : 66 / 300
# run_sim_xrun : 67 / 300
# run_sim_xrun : 68 / 300
# run_sim_xrun : 69 / 300
# run_sim_xrun : 70 / 300
# run_sim_xrun : 71 / 300
# run_sim_xrun : 72 / 300
# run_sim_xrun : 73 / 300
# run_sim_xrun : 74 / 300
# run_sim_xrun : 75 / 300
# run_sim_xrun : 76 / 300
# run_sim_xrun : 77 / 300
# run_sim_xrun : 78 / 300
# run_sim_xrun : 79 / 300
# run_sim_xrun : 80 / 300
# run_sim_xrun : 81 / 300
# run_sim_xrun : 82 / 300
# run_sim_xrun : 83 / 300
# run_sim_xrun : 84 / 300
# run_sim_xrun : 85 / 300
# run_sim_xrun : 86 / 300
# run_sim_xrun : 87 / 300
# run_sim_xrun : 88 / 300
# run_sim_xrun : 89 / 300
# run_sim_xrun : 90 / 300
# run_sim_xrun : 91 / 300
# run_sim_xrun : 92 / 300
# run_sim_xrun : 93 / 300
# run_sim_xrun : 94 / 300
# run_sim_xrun : 95 / 300
# run_sim_xrun : 96 / 300
# run_sim_xrun : 97 / 300
# run_sim_xrun : 98 / 300
# run_sim_xrun : 99 / 300
# run_sim_xrun : 100 / 300
# run_sim_xrun : 101 / 300
# run_sim_xrun : 102 / 300
# run_sim_xrun : 103 / 300
# run_sim_xrun : 104 / 300
# run_sim_xrun : 105 / 300
# run_sim_xrun : 106 / 300
# run_sim_xrun : 107 / 300
# run_sim_xrun : 108 / 300
# run_sim_xrun : 109 / 300
# run_sim_xrun : 110 / 300
# run_sim_xrun : 111 / 300
# run_sim_xrun : 112 / 300
# run_sim_xrun : 113 / 300
# run_sim_xrun : 114 / 300
# run_sim_xrun : 115 / 300
# run_sim_xrun : 116 / 300
# run_sim_xrun : 117 / 300
# run_sim_xrun : 118 / 300
# run_sim_xrun : 119 / 300
# run_sim_xrun : 120 / 300
# run_sim_xrun : 121 / 300
# run_sim_xrun : 122 / 300
# run_sim_xrun : 123 / 300
# run_sim_xrun : 124 / 300
# run_sim_xrun : 125 / 300
# run_sim_xrun : 126 / 300
# run_sim_xrun : 127 / 300
# run_sim_xrun : 128 / 300
# run_sim_xrun : 129 / 300
# run_sim_xrun : 130 / 300
# run_sim_xrun : 131 / 300
# run_sim_xrun : 132 / 300
# run_sim_xrun : 133 / 300
# run_sim_xrun : 134 / 300
# run_sim_xrun : 135 / 300
# run_sim_xrun : 136 / 300
# run_sim_xrun : 137 / 300
# run_sim_xrun : 138 / 300
# run_sim_xrun : 139 / 300
# run_sim_xrun : 140 / 300
# run_sim_xrun : 141 / 300
# run_sim_xrun : 142 / 300
# run_sim_xrun : 143 / 300
# run_sim_xrun : 144 / 300
# run_sim_xrun : 145 / 300
# run_sim_xrun : 146 / 300
# run_sim_xrun : 147 / 300
# run_sim_xrun : 148 / 300
# run_sim_xrun : 149 / 300
# run_sim_xrun : 150 / 300
# run_sim_xrun : 151 / 300
# run_sim_xrun : 152 / 300
# run_sim_xrun : 153 / 300
# run_sim_xrun : 154 / 300
# run_sim_xrun : 155 / 300
# run_sim_xrun : 156 / 300
# run_sim_xrun : 157 / 300
# run_sim_xrun : 158 / 300
# run_sim_xrun : 159 / 300
# run_sim_xrun : 160 / 300
# run_sim_xrun : 161 / 300
# run_sim_xrun : 162 / 300
# run_sim_xrun : 163 / 300
# run_sim_xrun : 164 / 300
# run_sim_xrun : 165 / 300
# run_sim_xrun : 166 / 300
# run_sim_xrun : 167 / 300
# run_sim_xrun : 168 / 300
# run_sim_xrun : 169 / 300
# run_sim_xrun : 170 / 300
# run_sim_xrun : 171 / 300
# run_sim_xrun : 172 / 300
# run_sim_xrun : 173 / 300
# run_sim_xrun : 174 / 300
# run_sim_xrun : 175 / 300
# run_sim_xrun : 176 / 300
# run_sim_xrun : 177 / 300
# run_sim_xrun : 178 / 300
# run_sim_xrun : 179 / 300
# run_sim_xrun : 180 / 300
# run_sim_xrun : 181 / 300
# run_sim_xrun : 182 / 300
# run_sim_xrun : 183 / 300
# run_sim_xrun : 184 / 300
# run_sim_xrun : 185 / 300
# run_sim_xrun : 186 / 300
# run_sim_xrun : 187 / 300
# run_sim_xrun : 188 / 300
# run_sim_xrun : 189 / 300
# run_sim_xrun : 190 / 300
# run_sim_xrun : 191 / 300
# run_sim_xrun : 192 / 300
# run_sim_xrun : 193 / 300
# run_sim_xrun : 194 / 300
# run_sim_xrun : 195 / 300
# run_sim_xrun : 196 / 300
# run_sim_xrun : 197 / 300
# run_sim_xrun : 198 / 300
# run_sim_xrun : 199 / 300
# run_sim_xrun : 200 / 300
# run_sim_xrun : 201 / 300
# run_sim_xrun : 202 / 300
# run_sim_xrun : 203 / 300
# run_sim_xrun : 204 / 300
# run_sim_xrun : 205 / 300
# run_sim_xrun : 206 / 300
# run_sim_xrun : 207 / 300
# run_sim_xrun : 208 / 300
# run_sim_xrun : 209 / 300
# run_sim_xrun : 210 / 300
# run_sim_xrun : 211 / 300
# run_sim_xrun : 212 / 300
# run_sim_xrun : 213 / 300
# run_sim_xrun : 214 / 300
# run_sim_xrun : 215 / 300
# run_sim_xrun : 216 / 300
# run_sim_xrun : 217 / 300
# run_sim_xrun : 218 / 300
# run_sim_xrun : 219 / 300
# run_sim_xrun : 220 / 300
# run_sim_xrun : 221 / 300
# run_sim_xrun : 222 / 300
# run_sim_xrun : 223 / 300
# run_sim_xrun : 224 / 300
# run_sim_xrun : 225 / 300
# run_sim_xrun : 226 / 300
# run_sim_xrun : 227 / 300
# run_sim_xrun : 228 / 300
# run_sim_xrun : 229 / 300
# run_sim_xrun : 230 / 300
# run_sim_xrun : 231 / 300
# run_sim_xrun : 232 / 300
# run_sim_xrun : 233 / 300
# run_sim_xrun : 234 / 300
# run_sim_xrun : 235 / 300
# run_sim_xrun : 236 / 300
# run_sim_xrun : 237 / 300
# run_sim_xrun : 238 / 300
# run_sim_xrun : 239 / 300
# run_sim_xrun : 240 / 300
# run_sim_xrun : 241 / 300
# run_sim_xrun : 242 / 300
# run_sim_xrun : 243 / 300
# run_sim_xrun : 244 / 300
# run_sim_xrun : 245 / 300
# run_sim_xrun : 246 / 300
# run_sim_xrun : 247 / 300
# run_sim_xrun : 248 / 300
# run_sim_xrun : 249 / 300
# run_sim_xrun : 250 / 300
# run_sim_xrun : 251 / 300
# run_sim_xrun : 252 / 300
# run_sim_xrun : 253 / 300
# run_sim_xrun : 254 / 300
# run_sim_xrun : 255 / 300
# run_sim_xrun : 256 / 300
# run_sim_xrun : 257 / 300
# run_sim_xrun : 258 / 300
# run_sim_xrun : 259 / 300
# run_sim_xrun : 260 / 300
# run_sim_xrun : 261 / 300
# run_sim_xrun : 262 / 300
# run_sim_xrun : 263 / 300
# run_sim_xrun : 264 / 300
# run_sim_xrun : 265 / 300
# run_sim_xrun : 266 / 300
# run_sim_xrun : 267 / 300
# run_sim_xrun : 268 / 300
# run_sim_xrun : 269 / 300
# run_sim_xrun : 270 / 300
# run_sim_xrun : 271 / 300
# run_sim_xrun : 272 / 300
# run_sim_xrun : 273 / 300
# run_sim_xrun : 274 / 300
# run_sim_xrun : 275 / 300
# run_sim_xrun : 276 / 300
# run_sim_xrun : 277 / 300
# run_sim_xrun : 278 / 300
# run_sim_xrun : 279 / 300
# run_sim_xrun : 280 / 300
# run_sim_xrun : 281 / 300
# run_sim_xrun : 282 / 300
# run_sim_xrun : 283 / 300
# run_sim_xrun : 284 / 300
# run_sim_xrun : 285 / 300
# run_sim_xrun : 286 / 300
# run_sim_xrun : 287 / 300
# run_sim_xrun : 288 / 300
# run_sim_xrun : 289 / 300
# run_sim_xrun : 290 / 300
# run_sim_xrun : 291 / 300
# run_sim_xrun : 292 / 300
# run_sim_xrun : 293 / 300
# run_sim_xrun : 294 / 300
# run_sim_xrun : 295 / 300
# run_sim_xrun : 296 / 300
# run_sim_xrun : 297 / 300
# run_sim_xrun : 298 / 300
# run_sim_xrun : 299 / 300
# run_sim_xrun : 300 / 300
# 292       1.0                 0.0                    45.0         112.5
# 293       1.0                 0.0                    45.0         112.5
# 294       1.0                 0.0                    45.0         237.5
# 295       1.0                 0.0                    45.0         237.5
# 296       1.0                 0.0                    45.0         237.5
# 297       1.0                 0.0                    90.0         237.5
# 298       1.0                 0.0                    90.0         237.5
# 299       1.0                 0.0                    90.0         237.5
#
#      plant_orientation  rmax    skew      wl
# 0                 90.0   0.7  0.2875  0.1325
# 1                 90.0   0.7  0.2875  0.3775
# 2                 90.0   0.7  0.2875  0.3775
# 3                 45.0   0.7  0.2875  0.3775
# 4                 45.0   0.3  0.2875  0.3775
# 5                 45.0   0.3  0.2875  0.3775
# 6                 45.0   0.3  0.2875  0.3775
# 7                 45.0   0.3  0.2875  0.3775
# 8                 45.0   0.3  0.2875  0.3775
# 9                 45.0   0.3  0.7625  0.3775
# 10                67.5   0.1  0.0500  0.3775
# 11                67.5   0.1  0.0500  0.3775
# 12                22.5   0.1  0.0500  0.3775
# 13                22.5   0.1  0.0500  0.3775
# 14                22.5   0.1  0.0500  0.1325
# 15                22.5   0.1  0.0500  0.1325
# 16                22.5   0.1  0.0500  0.1325
# 17                22.5   0.1  0.5250  0.1325
# 18                22.5   0.1  0.5250  0.1325
# 19                22.5   0.5  0.5250  0.1325
# 20                67.5   0.7  1.0000  0.3775
# 21                67.5   0.7  0.5250  0.3775
# 22                67.5   0.7  0.5250  0.3775
# 23                67.5   0.7  0.5250  0.3775
# 24                67.5   0.3  0.5250  0.3775
# 25                22.5   0.3  0.5250  0.3775
# 26                22.5   0.3  0.5250  0.3775
# 27                22.5   0.3  0.5250  0.3775
# 28                22.5   0.3  0.5250  0.3775
# 29                22.5   0.3  0.5250  0.1325
# ..                 ...   ...     ...     ...
# 270               90.0   0.9  1.0000  0.0100
# 271               45.0   0.9  1.0000  0.0100
# 272               45.0   0.9  1.0000  0.0100
# 273               45.0   0.9  0.5250  0.0100
# 274               45.0   0.9  0.5250  0.2550
# 275               45.0   0.9  0.5250  0.2550
# 276               45.0   0.9  0.5250  0.2550
# 277               45.0   0.9  0.5250  0.2550
# 278               45.0   0.9  0.5250  0.2550
# 279               45.0   0.5  0.5250  0.2550
# 280               45.0   0.5  0.0500  0.2550
# 281               45.0   0.5  0.0500  0.5000
# 282               45.0   0.5  0.0500  0.5000
# 283               45.0   0.5  0.5250  0.5000
# 284               45.0   0.5  0.5250  0.5000
# 285               45.0   0.9  0.5250  0.5000
# 286               45.0   0.9  0.5250  0.5000
# 287               45.0   0.9  0.5250  0.5000
# 288                0.0   0.9  0.5250  0.5000
# 289                0.0   0.9  0.5250  0.5000
# 290               90.0   0.1  0.5250  0.2550
# 291               90.0   0.1  0.5250  0.2550
# 292               45.0   0.1  0.5250  0.2550
# 293               45.0   0.1  0.5250  0.5000
# 294               45.0   0.1  0.5250  0.5000
# 295               45.0   0.1  0.5250  0.5000
# 296               45.0   0.1  0.5250  0.5000
# 297               45.0   0.1  0.5250  0.5000
# 298               45.0   0.1  0.0500  0.5000
# 299               45.0   0.5  0.0500  0.5000
#
# [300 rows x 14 columns]
